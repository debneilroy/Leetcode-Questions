# %% [markdown]
# ## https://leetcode.com/explore/interview/card/amazon/78/trees-and-graphs/2982/

# %%
"""
Given two words (beginWord and endWord), and a dictionary's word list, find the length of shortest 
transformation sequence from beginWord to endWord, such that:

    1. Only one letter can be changed at a time.
    2. Each transformed word must exist in the word list.
    
Note:

1. Return 0 if there is no such transformation sequence.
2. All words have the same length.
3. All words contain only lowercase alphabetic characters.
4. You may assume no duplicates in the word list.
5. You may assume beginWord and endWord are non-empty and are not the same.

Example 1:

Input:
beginWord = "hit",
endWord = "cog",
wordList = ["hot","dot","dog","lot","log","cog"]

Output: 5

Explanation: As one shortest transformation is "hit" -> "hot" -> "dot" -> "dog" -> "cog",
return its length 5.

Example 2:

Input:
beginWord = "hit"
endWord = "cog"
wordList = ["hot","dot","dog","lot","log"]

Output: 0

Explanation: The endWord "cog" is not in wordList, therefore no possible transformation.

"""
# Out:
# '\nGiven two words (beginWord and endWord), and a dictionary\'s word list, find the length of shortest \ntransformation sequence from beginWord to endWord, such that:\n\n    1. Only one letter can be changed at a time.\n    2. Each transformed word must exist in the word list.\n    \nNote:\n\n1. Return 0 if there is no such transformation sequence.\n2. All words have the same length.\n3. All words contain only lowercase alphabetic characters.\n4. You may assume no duplicates in the word list.\n5. You may assume beginWord and endWord are non-empty and are not the same.\n\nExample 1:\n\nInput:\nbeginWord = "hit",\nendWord = "cog",\nwordList = ["hot","dot","dog","lot","log","cog"]\n\nOutput: 5\n\nExplanation: As one shortest transformation is "hit" -> "hot" -> "dot" -> "dog" -> "cog",\nreturn its length 5.\n\nExample 2:\n\nInput:\nbeginWord = "hit"\nendWord = "cog"\nwordList = ["hot","dot","dog","lot","log"]\n\nOutput: 0\n\nExplanation: The endWord "cog" is not in wordList, therefore no possible transformation.\n\n'

# %% [markdown]
# <img src = "Capture20.png">

# %% [markdown]
# <img src = "Capture21.png">

# %% [markdown]
# <img src = "Capture22.png">

# %%
import collections
from collections import defaultdict
class Solution(object):
    def ladderLength(self, beginWord, endWord, wordList):
        """
        :type beginWord: str
        :type endWord: str
        :type wordList: List[str]
        :rtype: int
        """

        if endWord not in wordList or not endWord or not beginWord or not wordList:
            return 0

        # Since all words are of same length.
        L = len(beginWord)

        # Dictionary to hold combination of words that can be formed,
        # from any given word. By changing one letter at a time.
        all_combo_dict = defaultdict(list)
        for word in wordList:
            for i in range(L):
                # Key is the generic word
                # Value is a list of words which have the same intermediate generic word.
                all_combo_dict[word[:i] + "*" + word[i+1:]].append(word)
                
        print(all_combo_dict)
        print("\n")


        # Queue for BFS
        queue = collections.deque([(beginWord, 1)])
        # Visited to make sure we don't repeat processing same word.
        visited = {beginWord: True}
        while queue:
            current_word, level = queue.popleft()
            print('Current word', current_word)
            print('Level', level)
            print("\n")
            for i in range(L):
                # Intermediate words for current word
                intermediate_word = current_word[:i] + "*" + current_word[i+1:]
                print('Intermediate word', intermediate_word)
                print("\n")

                # Next states are all the words which share the same intermediate state.
                for word in all_combo_dict[intermediate_word]:
                    print('Word is', word)
                    print("\n")
                    # If at any point if we find what we are looking for
                    # i.e. the end word - we can return with the answer.
                    if word == endWord:
                        return level + 1
                    # Otherwise, add it to the BFS Queue. Also mark it visited
                    if word not in visited:
                        visited[word] = True
                        print('Visited', visited)
                        queue.append((word, level + 1))
                        print('Queue', queue)
                        print("\n")
                all_combo_dict[intermediate_word] = []
                print(all_combo_dict)
                print('---------------------------------------------------------------------------------------------------------------')
            print('...............................................................................................................')
        return 0

# %%
sol = Solution()

# %%
wordList = ["hot","dot","dog","lot","log","cog"]
beginWord = "hit"
endWord = "cog"
sol.ladderLength(beginWord, endWord, wordList)
# Out:
# defaultdict(<class 'list'>, {'*ot': ['hot', 'dot', 'lot'], 'h*t': ['hot'], 'ho*': ['hot'], 'd*t': ['dot'], 'do*': ['dot', 'dog'], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': ['lot'], 'lo*': ['lot', 'log'], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog']})
#
#
# Current word hit
# Level 1
#
#
# Intermediate word *it
#
#
# defaultdict(<class 'list'>, {'*ot': ['hot', 'dot', 'lot'], 'h*t': ['hot'], 'ho*': ['hot'], 'd*t': ['dot'], 'do*': ['dot', 'dog'], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': ['lot'], 'lo*': ['lot', 'log'], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog'], '*it': []})
# ---------------------------------------------------------------------------------------------------------------
# Intermediate word h*t
#
#
# Word is hot
#
#
# Visited {'hit': True, 'hot': True}
# Queue deque([('hot', 2)])
#
#
# defaultdict(<class 'list'>, {'*ot': ['hot', 'dot', 'lot'], 'h*t': [], 'ho*': ['hot'], 'd*t': ['dot'], 'do*': ['dot', 'dog'], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': ['lot'], 'lo*': ['lot', 'log'], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog'], '*it': []})
# ---------------------------------------------------------------------------------------------------------------
# Intermediate word hi*
#
#
# defaultdict(<class 'list'>, {'*ot': ['hot', 'dot', 'lot'], 'h*t': [], 'ho*': ['hot'], 'd*t': ['dot'], 'do*': ['dot', 'dog'], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': ['lot'], 'lo*': ['lot', 'log'], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog'], '*it': [], 'hi*': []})
# ---------------------------------------------------------------------------------------------------------------
# ...............................................................................................................
# Current word hot
# Level 2
#
#
# Intermediate word *ot
#
#
# Word is hot
#
#
# Word is dot
#
#
# Visited {'hit': True, 'hot': True, 'dot': True}
# Queue deque([('dot', 3)])
#
#
# Word is lot
#
#
# Visited {'hit': True, 'hot': True, 'dot': True, 'lot': True}
# Queue deque([('dot', 3), ('lot', 3)])
#
#
# defaultdict(<class 'list'>, {'*ot': [], 'h*t': [], 'ho*': ['hot'], 'd*t': ['dot'], 'do*': ['dot', 'dog'], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': ['lot'], 'lo*': ['lot', 'log'], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog'], '*it': [], 'hi*': []})
# ---------------------------------------------------------------------------------------------------------------
# Intermediate word h*t
#
#
# defaultdict(<class 'list'>, {'*ot': [], 'h*t': [], 'ho*': ['hot'], 'd*t': ['dot'], 'do*': ['dot', 'dog'], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': ['lot'], 'lo*': ['lot', 'log'], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog'], '*it': [], 'hi*': []})
# ---------------------------------------------------------------------------------------------------------------
# Intermediate word ho*
#
#
# Word is hot
#
#
# defaultdict(<class 'list'>, {'*ot': [], 'h*t': [], 'ho*': [], 'd*t': ['dot'], 'do*': ['dot', 'dog'], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': ['lot'], 'lo*': ['lot', 'log'], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog'], '*it': [], 'hi*': []})
# ---------------------------------------------------------------------------------------------------------------
# ...............................................................................................................
# Current word dot
# Level 3
#
#
# Intermediate word *ot
#
#
# defaultdict(<class 'list'>, {'*ot': [], 'h*t': [], 'ho*': [], 'd*t': ['dot'], 'do*': ['dot', 'dog'], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': ['lot'], 'lo*': ['lot', 'log'], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog'], '*it': [], 'hi*': []})
# ---------------------------------------------------------------------------------------------------------------
# Intermediate word d*t
#
#
# Word is dot
#
#
# defaultdict(<class 'list'>, {'*ot': [], 'h*t': [], 'ho*': [], 'd*t': [], 'do*': ['dot', 'dog'], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': ['lot'], 'lo*': ['lot', 'log'], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog'], '*it': [], 'hi*': []})
# ---------------------------------------------------------------------------------------------------------------
# Intermediate word do*
#
#
# Word is dot
#
#
# Word is dog
#
#
# Visited {'hit': True, 'hot': True, 'dot': True, 'lot': True, 'dog': True}
# Queue deque([('lot', 3), ('dog', 4)])
#
#
# defaultdict(<class 'list'>, {'*ot': [], 'h*t': [], 'ho*': [], 'd*t': [], 'do*': [], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': ['lot'], 'lo*': ['lot', 'log'], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog'], '*it': [], 'hi*': []})
# ---------------------------------------------------------------------------------------------------------------
# ...............................................................................................................
# Current word lot
# Level 3
#
#
# Intermediate word *ot
#
#
# defaultdict(<class 'list'>, {'*ot': [], 'h*t': [], 'ho*': [], 'd*t': [], 'do*': [], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': ['lot'], 'lo*': ['lot', 'log'], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog'], '*it': [], 'hi*': []})
# ---------------------------------------------------------------------------------------------------------------
# Intermediate word l*t
#
#
# Word is lot
#
#
# defaultdict(<class 'list'>, {'*ot': [], 'h*t': [], 'ho*': [], 'd*t': [], 'do*': [], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': [], 'lo*': ['lot', 'log'], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog'], '*it': [], 'hi*': []})
# ---------------------------------------------------------------------------------------------------------------
# Intermediate word lo*
#
#
# Word is lot
#
#
# Word is log
#
#
# Visited {'hit': True, 'hot': True, 'dot': True, 'lot': True, 'dog': True, 'log': True}
# Queue deque([('dog', 4), ('log', 4)])
#
#
# defaultdict(<class 'list'>, {'*ot': [], 'h*t': [], 'ho*': [], 'd*t': [], 'do*': [], '*og': ['dog', 'log', 'cog'], 'd*g': ['dog'], 'l*t': [], 'lo*': [], 'l*g': ['log'], 'c*g': ['cog'], 'co*': ['cog'], '*it': [], 'hi*': []})
# ---------------------------------------------------------------------------------------------------------------
# ...............................................................................................................
# Current word dog
# Level 4
#
#
# Intermediate word *og
#
#
# Word is dog
#
#
# Word is log
#
#
# Word is cog
# 5

# %% [markdown]
# <img src = "Capture23.png">
